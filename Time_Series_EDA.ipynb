# %% [markdown]
# <a href="https://colab.research.google.com/github/Bibhuti-MLAI/Time-Series-Forcasting/blob/main/Time_Series_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Time Series EDA

# %%
## Install Pandas Data Reader
# !pip install pandas-datareader
# Out:
# Requirement already satisfied: pandas-datareader in /usr/local/lib/python3.12/dist-packages (0.11.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from pandas-datareader) (6.1.1)
# Requirement already satisfied: pandas>=2.1.4 in /usr/local/lib/python3.12/dist-packages (from pandas-datareader) (2.2.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from pandas-datareader) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from pandas-datareader) (75.2.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1.4->pandas-datareader) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1.4->pandas-datareader) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1.4->pandas-datareader) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1.4->pandas-datareader) (2026.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pandas-datareader) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pandas-datareader) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pandas-datareader) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pandas-datareader) (2026.7.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.1.4->pandas-datareader) (1.17.0)

# %%
import pandas_datareader as pdr
import pandas as pd
from datetime import datetime

# %%
import yfinance as yf
from datetime import datetime

start_date = datetime(2017, 1, 1)
end_date = datetime.now()

df_tesla = yf.download('TSLA', start=start_date, end=end_date)
# Out:
# /tmp/ipykernel_1139/2844467969.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df_tesla = yf.download('TSLA', start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed

# %%
df_tesla.tail()
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker            TSLA        TSLA        TSLA        TSLA      TSLA
# Date
# 2026-08-14  342.269989  351.260010  335.329987  342.329987  45437100
# 2026-08-17  339.299988  345.450012  337.480011  340.690002  26037100
# 2026-08-18  336.869995  340.529999  331.119995  333.220001  27994500
# 2026-08-19  351.119995  351.619995  335.700012  338.890015  36613200
# 2026-08-20  343.799988  347.489990  338.959991  345.890015  19634313

# %%
df_tesla['High'].plot(figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
## xlimit and y limit
df_tesla['High'].plot(xlim=['2020-01-01','2021-09-01'],figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
## xlimit and y limit
df_tesla['High'].plot(xlim=['2020-01-01','2021-09-01'],ylim=[0,900],figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
## xlimit and y limit and coloring
df_tesla['High'].plot(xlim=['2020-01-01','2021-09-01'],ylim=[0,900],figsize=(12,4),ls='--',c='green')
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla.index
# Out:
# DatetimeIndex(['2017-01-03', '2017-01-04', '2017-01-05', '2017-01-06',
#                '2017-01-09', '2017-01-10', '2017-01-11', '2017-01-12',
#                '2017-01-13', '2017-01-17',
#                ...
#                '2026-08-07', '2026-08-10', '2026-08-11', '2026-08-12',
#                '2026-08-13', '2026-08-14', '2026-08-17', '2026-08-18',
#                '2026-08-19', '2026-08-20'],
#               dtype='datetime64[ns]', name='Date', length=2421, freq=None)

# %%
index=df_tesla.loc['2020-01-01':'2021-09-01'].index
share_open=df_tesla.loc['2020-01-01':'2021-09-01']['Open']

# %%
share_open
# Out:
# Ticker            TSLA
# Date
# 2020-01-02   28.299999
# 2020-01-03   29.366667
# 2020-01-06   29.364668
# 2020-01-07   30.760000
# 2020-01-08   31.580000
# ...                ...
# 2021-08-26  236.103333
# 2021-08-27  235.000000
# 2021-08-30  238.240005
# 2021-08-31  244.333328
# 2021-09-01  244.693329
#
# [421 rows x 1 columns]

# %%
index
# Out:
# DatetimeIndex(['2020-01-02', '2020-01-03', '2020-01-06', '2020-01-07',
#                '2020-01-08', '2020-01-09', '2020-01-10', '2020-01-13',
#                '2020-01-14', '2020-01-15',
#                ...
#                '2021-08-19', '2021-08-20', '2021-08-23', '2021-08-24',
#                '2021-08-25', '2021-08-26', '2021-08-27', '2021-08-30',
#                '2021-08-31', '2021-09-01'],
#               dtype='datetime64[ns]', name='Date', length=421, freq=None)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
figure,axis=plt.subplots()
plt.tight_layout()
## Preventing overlapping
figure.autofmt_xdate()
axis.plot(index,share_open)

# %%
## Datetime Index

# %%
df_tesla=df_tesla.reset_index()

# %%
df_tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2421 entries, 0 to 2420
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Date, )        2421 non-null   datetime64[ns]
#  1   (Close, TSLA)   2421 non-null   float64
#  2   (High, TSLA)    2421 non-null   float64
#  3   (Low, TSLA)     2421 non-null   float64
#  4   (Open, TSLA)    2421 non-null   float64
#  5   (Volume, TSLA)  2421 non-null   int64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 113.6 KB

# %%
df_tesla=df_tesla.set_index('Date',drop=True)

# %%
df_tesla.head()
# Out:
# Price           Close       High        Low       Open     Volume
# Ticker           TSLA       TSLA       TSLA       TSLA       TSLA
# Date
# 2017-01-03  14.466000  14.688667  14.064000  14.324000   88849500
# 2017-01-04  15.132667  15.200000  14.287333  14.316667  168202500
# 2017-01-05  15.116667  15.165333  14.796667  15.094667   88675500
# 2017-01-06  15.267333  15.354000  15.030000  15.128667   82918500
# 2017-01-09  15.418667  15.461333  15.200000  15.264667   59692500

# %%
## datetime
from datetime import datetime

# %%
datetime(2021,11,21)
# Out:
# datetime.datetime(2021, 11, 21, 0, 0)

# %%
datetime.now()
# Out:
# datetime.datetime(2026, 8, 20, 17, 17, 26, 115535)

# %%
date=datetime(2021,11,21)

# %%
date
# Out:
# datetime.datetime(2021, 11, 21, 0, 0)

# %%
date.date()
# Out:
# datetime.date(2021, 11, 21)

# %%
date.day
# Out:
# 21

# %%
date.weekday()
# Out:
# 6

# %%
date.year
# Out:
# 2021

# %%
date.month
# Out:
# 11

# %% [markdown]
# ## Time Resampling

# %%
df_tesla.head()
# Out:
# Price           Close       High        Low       Open     Volume
# Ticker           TSLA       TSLA       TSLA       TSLA       TSLA
# Date
# 2017-01-03  14.466000  14.688667  14.064000  14.324000   88849500
# 2017-01-04  15.132667  15.200000  14.287333  14.316667  168202500
# 2017-01-05  15.116667  15.165333  14.796667  15.094667   88675500
# 2017-01-06  15.267333  15.354000  15.030000  15.128667   82918500
# 2017-01-09  15.418667  15.461333  15.200000  15.264667   59692500

# %%
df_tesla.resample(rule='A').min()
# Out:
# /tmp/ipykernel_1139/2338822268.py:1: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   df_tesla.resample(rule='A').min()
# Price            Close        High         Low        Open    Volume
# Ticker            TSLA        TSLA        TSLA        TSLA      TSLA
# Date
# 2017-12-31   14.466000   14.688667   14.064000   14.316667  32800500
# 2018-12-31   16.704000   17.355333   16.306000   16.851999  46210500
# 2019-12-31   11.931333   12.445333   11.799333   12.073333  36984000
# 2020-12-31   24.081333   26.990667   23.367332   24.980000  52073100
# 2021-12-31  187.666672  188.736664  179.830002  184.183334  29401800
# 2022-12-31  109.099998  116.269997  108.239998  110.349998  41864700
# 2023-12-31  108.099998  111.750000  101.809998  103.000000  65125200
# 2024-12-31  142.050003  144.440002  138.800003  140.559998  37167600
# 2025-12-31  221.860001  230.100006  214.250000  223.779999  36252900
# 2026-12-31  298.320007  309.059998  297.380005  302.700012  19634313

# %%
df_tesla.resample(rule='A').max()
# Out:
# /tmp/ipykernel_1139/3203370108.py:1: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   df_tesla.resample(rule='A').max()
# Price            Close        High         Low        Open     Volume
# Ticker            TSLA        TSLA        TSLA        TSLA       TSLA
# Date
# 2017-12-31   25.666668   25.974001   25.290001   25.779333  296871000
# 2018-12-31   25.304667   25.830667   24.474667   25.000000  504745500
# 2019-12-31   28.729334   29.020666   28.423332   29.000000  450091500
# 2020-12-31  235.223328  239.573334  230.373337  233.330002  914082000
# 2021-10-01  1243.489990  1217.000000  1234.410034  1229.910034   62852100.0
# 2022-01-03  1208.000000  1136.040039  1189.550049  1199.780029   50521900.0
#
#               Adj Close
# Date
# 2017-01-02    55.660000
# 2017-04-03    76.690002
# 2017-07-03    77.000000
# 2017-10-02    71.930000
# 2018-01-01    71.484001
# 2018-04-02    74.166000
# 2018-07-02    75.914001
# 2018-10-01    75.358002
# 2019-01-01    69.461998
# 2019-04-01    58.362000
# 2019-07-01    52.976002
# 2019-10-01    86.188004
# 2020-01-01   183.483994
# 2020-04-01   215.962006
# 2020-07-01   498.320007
# 2020-10-01   705.669983
# 2021-01-01   883.090027
# 2021-04-01   762.320007
# 2021-07-01   791.359985
# 2021-10-01  1229.910034
# 2022-01-03  1199.780029

# %%
##plotting
df_tesla['Open'].resample(rule='A').mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla['Open'].resample(rule='M').max().plot(kind='bar',figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla['High'].rolling(11).max().head(20)
# Out:
# Date
# 2017-02-27          NaN
# 2017-02-28          NaN
# 2017-03-01          NaN
# 2017-03-02          NaN
# 2017-03-03          NaN
# 2017-03-06          NaN
# 2017-03-07          NaN
# 2017-03-08          NaN
# 2017-03-09          NaN
# 2017-03-10          NaN
# 2017-03-13    50.970001
# 2017-03-14    51.624001
# 2017-03-15    52.200001
# 2017-03-16    53.150002
# 2017-03-17    53.150002
# 2017-03-20    53.150002
# 2017-03-21    53.150002
# 2017-03-22    53.150002
# 2017-03-23    53.150002
# 2017-03-24    53.150002
# Name: High, dtype: float64

# %%
df_tesla.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2017-02-27  49.672001  48.402000  49.633999  49.245998  57304000.0  49.245998
# 2017-02-28  50.200001  48.779999  48.838001  49.998001  30390500.0  49.998001
# 2017-03-01  50.970001  49.821999  50.835999  50.004002  24047500.0  50.004002
# 2017-03-02  50.655998  49.653999  49.942001  50.096001  16759000.0  50.096001
# 2017-03-03  50.380001  49.799999  50.147999  50.313999  14597000.0  50.313999

# %%
df_tesla['Open:30 days rolling']=df_tesla['Open'].rolling(30).mean()

# %%
df_tesla.head(31)
# Out:
#                  High        Low       Open      Close      Volume  Adj Close  \
# Date
# 2017-02-27  49.672001  48.402000  49.633999  49.245998  57304000.0  49.245998
# 2017-02-28  50.200001  48.779999  48.838001  49.998001  30390500.0  49.998001
# 2017-03-01  50.970001  49.821999  50.835999  50.004002  24047500.0  50.004002
# 2017-03-02  50.655998  49.653999  49.942001  50.096001  16759000.0  50.096001
# 2017-03-03  50.380001  49.799999  50.147999  50.313999  14597000.0  50.313999
# 2017-03-06  50.340000  49.501999  49.582001  50.242001  16777500.0  50.242001
# 2017-03-07  50.778000  49.664001  50.383999  49.717999  17297500.0  49.717999
# 2017-03-08  50.014000  49.063999  49.400002  49.374001  18626000.0  49.374001
# 2017-03-09  49.731998  48.599998  49.526001  48.980000  19396500.0  48.980000
# 2017-03-10  49.299999  48.599998  49.242001  48.737999  15331500.0  48.737999
# 2017-03-13  49.369999  48.556000  48.964001  49.234001  15113000.0  49.234001
# 2017-03-14  51.624001  49.203999  49.222000  51.599998  37992000.0  51.599998
# 2017-03-15  52.200001  50.854000  51.400002  51.146000  26654000.0  51.146000
# 2017-03-16  53.150002  51.812000  52.480000  52.410000  35661000.0  52.410000
# 2017-03-17  53.066002  52.240002  52.799999  52.299999  32487500.0  52.299999
# 2017-03-20  52.910000  51.764000  52.119999  52.383999  18071500.0  52.383999
# 2017-03-21  52.959999  50.048000  52.566002  50.136002  34543000.0  50.136002
# 2017-03-22  51.014000  50.102001  50.312000  51.001999  20296500.0  51.001999
# 2017-03-23  51.534000  50.660000  51.077999  50.956001  16601000.0  50.956001
# 2017-03-24  52.778000  51.001999  51.139999  52.632000  28236500.0  52.632000
# 2017-03-27  54.113998  51.950001  52.119999  54.043999  31154000.0  54.043999
# 2017-03-28  56.136002  55.000000  55.403999  55.490002  39938000.0  55.490002
# 2017-03-29  55.919998  55.108002  55.667999  55.476002  18381000.0  55.476002
# 2017-03-30  56.400002  55.442001  55.608002  55.584000  20742000.0  55.584000
# 2017-03-31  55.936001  55.264000  55.745998  55.660000  16473000.0  55.660000
# 2017-04-03  59.799999  56.916000  57.380001  59.703999  69443000.0  59.703999
# 2017-04-04  60.962002  58.905998  59.377998  60.740002  50673000.0  60.740002
# 2017-04-05  60.976002  58.840000  60.408001  59.000000  39404500.0  59.000000
# 2017-04-06  60.388000  58.820000  59.375999  59.740002  27603000.0  59.740002
# 2017-04-07  60.537998  59.430000  59.500000  60.507999  22898000.0  60.507999
# 2017-04-10  62.745998  61.742001  61.830002  62.478001  38322500.0  62.478001
#
#             Open:30 days rolling
# Date
# 2017-02-27                   NaN
# 2017-02-28                   NaN
# 2017-03-01                   NaN
# 2017-03-02                   NaN
# 2017-03-03                   NaN
# 2017-03-06                   NaN
# 2017-03-07                   NaN
# 2017-03-08                   NaN
# 2017-03-09                   NaN
# 2017-03-10                   NaN
# 2017-03-13                   NaN
# 2017-03-14                   NaN
# 2017-03-15                   NaN
# 2017-03-16                   NaN
# 2017-03-17                   NaN
# 2017-03-20                   NaN
# 2017-03-21                   NaN
# 2017-03-22                   NaN
# 2017-03-23                   NaN
# 2017-03-24                   NaN
# 2017-03-27                   NaN
# 2017-03-28                   NaN
# 2017-03-29                   NaN
# 2017-03-30                   NaN
# 2017-03-31                   NaN
# 2017-04-03                   NaN
# 2017-04-04                   NaN
# 2017-04-05                   NaN
# 2017-04-06                   NaN
# 2017-04-07             52.673400
# 2017-04-10             53.079933

# %%
df_tesla[['Open','Open:30 days rolling']].plot(figsize=(12,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ##Assignment
# ##news
# 1. Read the Microsoft Data using Pandas Data reader
# 2. Get the maximum price of the share from 2017 to 2022
# 3. Which is the date of the highest price of the stock?
# 4. Which is the date of the lowest price of the stock?
